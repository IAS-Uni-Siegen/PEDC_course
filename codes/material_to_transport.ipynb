# %% [markdown]
# # Tutorial 1 - From band gap to carrier density, conductivity, Hall coefficient, and Fermi-level shift
#
# **Course:** Power Electronics Devices and Components
# **Lecture linkage:** energy bands, intrinsic carrier concentration, doping, majority/minority carriers, conductivity, Hall coefficient, and Fermi-level shift
#
# ## Why this tutorial matters
# This notebook is designed as an **integrated tutorial**. Students often learn band gap, doping, conductivity, Hall coefficient, and Fermi level as separate formulas. In reality, these quantities are part of one physical chain:
#
# **band gap \(\rightarrow\) intrinsic carrier concentration \(\rightarrow\) doping response \(\rightarrow\) carrier populations \(\rightarrow\) conductivity \(\rightarrow\) Hall response \(\rightarrow\) Fermi-level shift**
#
# By coding the full chain, students can see how a change in **material** or **doping** propagates through multiple quantities at once.
#
# ## Governing equations used in this notebook
# All concentrations are treated in **cm\(^{-3}\)** and mobilities in **cm\(^2\)/(V·s)**.
#
# ### 1. Intrinsic carrier concentration
# \[
# n_i = \sqrt{N_cN_v}\exp\left(-\frac{E_g}{2kT}\right)
# \]
#
# ### 2. Charge neutrality and mass-action law
# For compensated material with donor concentration \(N_D\) and acceptor concentration \(N_A\),
# \[
# n - p = N_D - N_A, \qquad np = n_i^2
# \]
#
# For the n-type cases in this notebook, the equilibrium solution is
# \[
# n = \frac{(N_D-N_A) + \sqrt{(N_D-N_A)^2 + 4n_i^2}}{2},
# \qquad
# p = \frac{n_i^2}{n}
# \]
#
# ### 3. Conductivity and resistivity
# \[
# \sigma = q(n\mu_n + p\mu_p)
# \]
# \[
# \rho = \frac{1}{\sigma}
# \]
#
# In this notebook, \(\sigma\) is reported in **S/cm** and \(\rho\) in **\(\Omega\cdot\)cm**.
#
# ### 4. Hall coefficient (single-carrier estimate)
# When one carrier type clearly dominates,
# \[
# R_H \approx -\frac{1}{qn} \quad \text{for n-type}, \qquad
# R_H \approx +\frac{1}{qp} \quad \text{for p-type}
# \]
#
# In this notebook, \(R_H\) is reported in **cm\(^3\)/C**.
#
# ### 5. Fermi-level shift relative to the intrinsic level
# For non-degenerate n-type behavior,
# \[
# E_F - E_i = kT \ln\left(\frac{n}{n_i}\right)
# \]
#
# This quantity is reported in **eV**.
#
# ## Fixed values for this tutorial
# Use the following values unless a question explicitly asks you to vary them:
#
# - Elementary charge: \(q = 1.602\times10^{-19}\,\mathrm{C}\)
# - Boltzmann constant: \(k = 8.617\times10^{-5}\,\mathrm{eV/K}\)
#
# ## Material parameters to be used
# Use the following material values throughout the tutorial:
#
# | Material | \(E_g\) (eV) | \(N_c\) (cm\(^{-3}\)) | \(N_v\) (cm\(^{-3}\)) | \(\mu_n\) (cm\(^2\)/(V·s)) | \(\mu_p\) (cm\(^2\)/(V·s)) |
# |---|---:|---:|---:|---:|---:|
# | Ge  | 0.66 | \(1.04\times10^{19}\) | \(6.0\times10^{18}\) | 3900 | 1900 |
# | Si  | 1.12 | \(2.8\times10^{19}\)  | \(1.04\times10^{19}\) | 1350 | 480 |
# | SiC | 3.26 | \(1.6\times10^{19}\)  | \(2.5\times10^{19}\)  | 900  | 120 |
# | GaN | 3.40 | \(2.3\times10^{18}\)  | \(4.6\times10^{19}\)  | 1000 | 200 |
#
# ## Student tasks
#
# ### Part A - Effect of band gap and material choice
# Use the four materials **Ge, Si, SiC, and GaN** at:
#
# - Temperature: \(T=300\,\mathrm{K}\)
# - Doping: \(N_D = 0\), \(N_A = 0\) (intrinsic case)
#
# Tasks:
# 1. Compute the intrinsic carrier concentration \(n_i\) for all four materials.
# 2. Compute the intrinsic conductivity \(\sigma_i = qn_i(\mu_n+\mu_p)\).
# 3. Plot \(n_i\) for all four materials on a logarithmic scale.
# 4. Plot \(\sigma_i\) for all four materials on a logarithmic scale.
# 5. Explain how increasing band gap changes \(n_i\) and why this matters for power electronics.
#
# ### Part B - Donor doping sweep in silicon
# Use **silicon** at:
#
# - Temperature: \(T=300\,\mathrm{K}\)
# - Acceptor concentration: \(N_A = 0\)
# - Donor concentrations:
# \[
# N_D = [10^{14},\;10^{15},\;10^{16},\;10^{17},\;10^{18}] \;\mathrm{cm^{-3}}
# \]
#
# Tasks:
# 1. For each \(N_D\), calculate \(n\), \(p\), \(\sigma\), \(\rho\), \(R_H\), and \(E_F-E_i\).
# 2. Plot \(n\) and \(p\) against \(N_D\).
# 3. Plot \(\sigma\) and \(\rho\) against \(N_D\).
# 4. Plot \(R_H\) and \(E_F-E_i\) against \(N_D\).
# 5. Explain how increasing donor doping changes majority carriers, minority carriers, conductivity, Hall response, and Fermi-level position.
#
# ### Part C - Thermal stability of a wide-band-gap material
# Compare **Si** and **GaN** using:
#
# - Donor concentration: \(N_D = 10^{14}\,\mathrm{cm^{-3}}\)
# - Acceptor concentration: \(N_A = 0\)
# - Temperatures:
# \[
# T = [300,\;450,\;600]\;\mathrm{K}
# \]
#
# Tasks:
# 1. For both materials and all three temperatures, compute \(n_i\), \(n\), \(p\), \(\sigma\), \(R_H\), and \(E_F-E_i\).
# 2. Plot \(n_i\) versus temperature for Si and GaN.
# 3. Plot conductivity versus temperature for Si and GaN.
# 4. Plot \(E_F-E_i\) versus temperature for Si and GaN.
# 5. Explain why the wide-band-gap material remains more extrinsic-stable as temperature increases.
#
# ## Student questions
# 1. How does a larger band gap affect \(n_i\), intrinsic conductivity, and thermal stability?
# 2. How does increasing donor doping change \(n\), \(p\), \(\sigma\), \(\rho\), \(R_H\), and \(E_F-E_i\)?
# 3. Why does the magnitude of the Hall coefficient usually decrease as donor doping increases?
# 4. Why do wide-band-gap materials remain more stable against intrinsic takeover at elevated temperature?
# 5. Which quantities in this notebook are mainly **material properties**, and which are **design variables**?

# %%
import numpy as np
import matplotlib.pyplot as plt

# ---------------------------------------------------------------------
# Fixed constants and material data for the tutorial
# ---------------------------------------------------------------------
q = 1.602176634e-19              # C
k_eV = 8.617333262145e-5         # eV/K

materials = {
    'Ge':  {'Eg': 0.66, 'Nc': 1.04e19, 'Nv': 6.0e18,  'mu_n': 3900.0, 'mu_p': 1900.0},
    'Si':  {'Eg': 1.12, 'Nc': 2.8e19,  'Nv': 1.04e19, 'mu_n': 1350.0, 'mu_p': 480.0},
    'SiC': {'Eg': 3.26, 'Nc': 1.6e19,  'Nv': 2.5e19,  'mu_n': 900.0,  'mu_p': 120.0},
    'GaN': {'Eg': 3.40, 'Nc': 2.3e18,  'Nv': 4.6e19,  'mu_n': 1000.0, 'mu_p': 200.0},
}

def intrinsic_carrier_concentration(Eg, Nc, Nv, T):
    return np.sqrt(Nc * Nv) * np.exp(-Eg / (2 * k_eV * T))

def solve_carriers(ni, ND, NA=0.0):
    # Equilibrium electron and hole concentrations from charge neutrality and mass action.
    net = ND - NA
    n = 0.5 * (net + np.sqrt(net**2 + 4 * ni**2))
    p = ni**2 / n
    return n, p

def conductivity(q, n, p, mu_n, mu_p):
    # Conductivity in S/cm when n, p are in cm^-3 and mobility in cm^2/(V s).
    return q * (n * mu_n + p * mu_p)

def resistivity(sigma):
    return 1.0 / sigma

def hall_coefficient_n_type(q, n):
    # Single-carrier estimate in cm^3/C for n-type-dominant material.
    return -1.0 / (q * n)

def fermi_shift_from_intrinsic(n, ni, T):
    # E_F - E_i in eV for non-degenerate n-type cases.
    return k_eV * T * np.log(n / ni)

print("Fixed constants used in this tutorial")
print(f"  q    = {q:.6e} C")
print(f"  k    = {k_eV:.6e} eV/K")
print("\nMaterial values")
for name, mat in materials.items():
    print(f"  {name}: Eg = {mat['Eg']:.2f} eV, Nc = {mat['Nc']:.2e} cm^-3, Nv = {mat['Nv']:.2e} cm^-3, "
          f"mu_n = {mat['mu_n']:.0f} cm^2/Vs, mu_p = {mat['mu_p']:.0f} cm^2/Vs")
# Out:
# Fixed constants used in this tutorial
#   q    = 1.602177e-19 C
#   k    = 8.617333e-05 eV/K
#
# Material values
#   Ge: Eg = 0.66 eV, Nc = 1.04e+19 cm^-3, Nv = 6.00e+18 cm^-3, mu_n = 3900 cm^2/Vs, mu_p = 1900 cm^2/Vs
#   Si: Eg = 1.12 eV, Nc = 2.80e+19 cm^-3, Nv = 1.04e+19 cm^-3, mu_n = 1350 cm^2/Vs, mu_p = 480 cm^2/Vs
#   SiC: Eg = 3.26 eV, Nc = 1.60e+19 cm^-3, Nv = 2.50e+19 cm^-3, mu_n = 900 cm^2/Vs, mu_p = 120 cm^2/Vs
#   GaN: Eg = 3.40 eV, Nc = 2.30e+18 cm^-3, Nv = 4.60e+19 cm^-3, mu_n = 1000 cm^2/Vs, mu_p = 200 cm^2/Vs

# %%
# ---------------------------------------------------------------------
# Part A - Material comparison at T = 300 K, intrinsic case
# ---------------------------------------------------------------------
T_A = 300.0
material_names = ['Ge', 'Si', 'SiC', 'GaN']

ni_A = []
sigma_i_A = []

for name in material_names:
    mat = materials[name]
    ni = intrinsic_carrier_concentration(mat['Eg'], mat['Nc'], mat['Nv'], T_A)
    sigma_i = conductivity(q, ni, ni, mat['mu_n'], mat['mu_p'])
    ni_A.append(ni)
    sigma_i_A.append(sigma_i)
    print(f"{name:>3s} at {T_A:.0f} K: ni = {ni:.3e} cm^-3, sigma_i = {sigma_i:.3e} S/cm")

ni_A = np.array(ni_A)
sigma_i_A = np.array(sigma_i_A)

plt.figure(figsize=(10, 6))
plt.bar(material_names, ni_A)
plt.yscale('log')
plt.ylabel(r'Intrinsic carrier concentration $n_i$ (cm$^{-3}$)')
plt.title('Part A1: Intrinsic carrier concentration of Ge, Si, SiC, and GaN at 300 K')
plt.grid(True, which='both', linestyle='--', linewidth=0.5, axis='y')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
plt.bar(material_names, sigma_i_A)
plt.yscale('log')
plt.ylabel(r'Intrinsic conductivity $\sigma_i$ (S/cm)')
plt.title('Part A2: Intrinsic conductivity of Ge, Si, SiC, and GaN at 300 K')
plt.grid(True, which='both', linestyle='--', linewidth=0.5, axis='y')
plt.tight_layout()
plt.show()
# Out:
#  Ge at 300 K: ni = 2.259e+13 cm^-3, sigma_i = 2.099e-02 S/cm
#  Si at 300 K: ni = 6.676e+09 cm^-3, sigma_i = 1.957e-06 S/cm
# SiC at 300 K: ni = 8.284e-09 cm^-3, sigma_i = 1.354e-24 S/cm
# GaN at 300 K: ni = 2.841e-10 cm^-3, sigma_i = 5.462e-26 S/cm

# %%
# ---------------------------------------------------------------------
# Part B - Donor-doping sweep in silicon at T = 300 K
# ---------------------------------------------------------------------
mat = materials['Si']
T_B = 300.0
NA_B = 0.0
ND_task = np.array([1e14, 1e15, 1e16, 1e17, 1e18])     # explicit task values
ND_plot = np.logspace(14, 18, 300)                     # dense sweep for smooth plots

ni_B = intrinsic_carrier_concentration(mat['Eg'], mat['Nc'], mat['Nv'], T_B)
n_B, p_B = solve_carriers(ni_B, ND_plot, NA_B)
sigma_B = conductivity(q, n_B, p_B, mat['mu_n'], mat['mu_p'])
rho_B = resistivity(sigma_B)
RH_B = hall_coefficient_n_type(q, n_B)
EFEi_B = fermi_shift_from_intrinsic(n_B, ni_B, T_B)

# Values exactly requested in the task statement
n_task, p_task = solve_carriers(ni_B, ND_task, NA_B)
sigma_task = conductivity(q, n_task, p_task, mat['mu_n'], mat['mu_p'])
rho_task = resistivity(sigma_task)
RH_task = hall_coefficient_n_type(q, n_task)
EFEi_task = fermi_shift_from_intrinsic(n_task, ni_B, T_B)

print(f"Silicon at {T_B:.0f} K: ni = {ni_B:.3e} cm^-3")
print("\nTask values for Part B")
print("ND (cm^-3)      n (cm^-3)        p (cm^-3)        sigma (S/cm)     rho (ohm*cm)     RH (cm^3/C)      EF-Ei (eV)")
for ND_i, n_i, p_i, s_i, r_i, RH_i, E_i in zip(ND_task, n_task, p_task, sigma_task, rho_task, RH_task, EFEi_task):
    print(f"{ND_i:>10.2e}   {n_i:>12.3e}   {p_i:>12.3e}   {s_i:>12.3e}   {r_i:>12.3e}   {RH_i:>12.3e}   {E_i:>10.3f}")

plt.figure(figsize=(10, 6))
plt.loglog(ND_plot, n_B, label=r'Electron concentration $n$')
plt.loglog(ND_plot, p_B, label=r'Hole concentration $p$')
plt.axhline(ni_B, linestyle='--', label=r'$n_i$ at 300 K')
plt.scatter(ND_task, n_task, marker='o')
plt.scatter(ND_task, p_task, marker='s')
plt.xlabel(r'Donor concentration $N_D$ (cm$^{-3}$)')
plt.ylabel(r'Carrier concentration (cm$^{-3}$)')
plt.title('Part B1: Majority and minority carriers in n-type silicon')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
plt.loglog(ND_plot, sigma_B, label=r'Conductivity $\sigma$')
plt.loglog(ND_plot, rho_B, label=r'Resistivity $\rho$')
plt.scatter(ND_task, sigma_task, marker='o')
plt.scatter(ND_task, rho_task, marker='s')
plt.xlabel(r'Donor concentration $N_D$ (cm$^{-3}$)')
plt.ylabel('Conductivity / Resistivity')
plt.title('Part B2: Conductivity rises and resistivity falls with donor doping')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.semilogx(ND_plot, RH_B, label=r'Hall coefficient $R_H$')
ax1.scatter(ND_task, RH_task, marker='o')
ax1.set_xlabel(r'Donor concentration $N_D$ (cm$^{-3}$)')
ax1.set_ylabel(r'Hall coefficient $R_H$ (cm$^3$/C)')
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

ax2 = ax1.twinx()
ax2.semilogx(ND_plot, EFEi_B, color='tab:red', label=r'$E_F - E_i$')
ax2.scatter(ND_task, EFEi_task, color='tab:red', marker='s')
ax2.set_ylabel(r'$E_F - E_i$ (eV)', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

plt.title('Part B3: Hall coefficient magnitude and Fermi-level shift vs donor doping')
plt.tight_layout()
plt.show()
# Out:
# Silicon at 300 K: ni = 6.676e+09 cm^-3
#
# Task values for Part B
# ND (cm^-3)      n (cm^-3)        p (cm^-3)        sigma (S/cm)     rho (ohm*cm)     RH (cm^3/C)      EF-Ei (eV)
#   1.00e+14      1.000e+14      4.457e+05      2.163e-02      4.623e+01     -6.242e+04        0.249
#   1.00e+15      1.000e+15      4.457e+04      2.163e-01      4.623e+00     -6.242e+03        0.308
#   1.00e+16      1.000e+16      4.457e+03      2.163e+00      4.623e-01     -6.242e+02        0.368
#   1.00e+17      1.000e+17      4.457e+02      2.163e+01      4.623e-02     -6.242e+01        0.427
#   1.00e+18      1.000e+18      4.457e+01      2.163e+02      4.623e-03     -6.242e+00        0.487

# %%
# ---------------------------------------------------------------------
# Part C - Thermal stability comparison: Si versus GaN
# ---------------------------------------------------------------------
ND_C = 1e14
NA_C = 0.0
T_values = np.array([300.0, 450.0, 600.0])
compare_materials = ['Si', 'GaN']

results = {}
for name in compare_materials:
    mat = materials[name]
    ni_list = []
    n_list = []
    p_list = []
    sigma_list = []
    RH_list = []
    EFEi_list = []

    for T in T_values:
        ni = intrinsic_carrier_concentration(mat['Eg'], mat['Nc'], mat['Nv'], T)
        n, p = solve_carriers(ni, ND_C, NA_C)
        sigma = conductivity(q, n, p, mat['mu_n'], mat['mu_p'])
        RH = hall_coefficient_n_type(q, n)
        EFEi = fermi_shift_from_intrinsic(n, ni, T)

        ni_list.append(ni)
        n_list.append(n)
        p_list.append(p)
        sigma_list.append(sigma)
        RH_list.append(RH)
        EFEi_list.append(EFEi)

    results[name] = {
        'ni': np.array(ni_list),
        'n': np.array(n_list),
        'p': np.array(p_list),
        'sigma': np.array(sigma_list),
        'RH': np.array(RH_list),
        'EFEi': np.array(EFEi_list),
    }

print(f"Part C fixed doping: ND = {ND_C:.1e} cm^-3, NA = {NA_C:.1e} cm^-3")
for name in compare_materials:
    print(f"\n{name} results")
    print("T (K)      ni (cm^-3)        n (cm^-3)        p (cm^-3)        sigma (S/cm)     RH (cm^3/C)      EF-Ei (eV)")
    for T, ni_i, n_i, p_i, s_i, RH_i, E_i in zip(
        T_values, results[name]['ni'], results[name]['n'], results[name]['p'],
        results[name]['sigma'], results[name]['RH'], results[name]['EFEi']
    ):
        print(f"{T:>5.0f}   {ni_i:>12.3e}   {n_i:>12.3e}   {p_i:>12.3e}   {s_i:>12.3e}   {RH_i:>12.3e}   {E_i:>10.3f}")

plt.figure(figsize=(10, 6))
for name in compare_materials:
    plt.semilogy(T_values, results[name]['ni'], marker='o', label=f'{name}')
plt.xlabel('Temperature (K)')
plt.ylabel(r'Intrinsic carrier concentration $n_i$ (cm$^{-3}$)')
plt.title('Part C1: Temperature dependence of $n_i$ for Si and GaN')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
for name in compare_materials:
    plt.semilogy(T_values, results[name]['sigma'], marker='o', label=f'{name}')
plt.xlabel('Temperature (K)')
plt.ylabel(r'Conductivity $\sigma$ (S/cm)')
plt.title('Part C2: Conductivity versus temperature at fixed donor doping')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
for name in compare_materials:
    plt.plot(T_values, results[name]['EFEi'], marker='o', label=f'{name}')
plt.xlabel('Temperature (K)')
plt.ylabel(r'$E_F - E_i$ (eV)')
plt.title('Part C3: Fermi-level shift versus temperature at fixed donor doping')
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Part C fixed doping: ND = 1.0e+14 cm^-3, NA = 0.0e+00 cm^-3
#
# Si results
# T (K)      ni (cm^-3)        n (cm^-3)        p (cm^-3)        sigma (S/cm)     RH (cm^3/C)      EF-Ei (eV)
#   300      6.676e+09      1.000e+14      4.457e+05      2.163e-02     -6.242e+04        0.249
#   450      9.128e+12      1.008e+14      8.264e+11      2.187e-02     -6.190e+04        0.093
#   600      3.375e+14      3.912e+14      2.912e+14      1.070e-01     -1.595e+04        0.008
#
# GaN results
# T (K)      ni (cm^-3)        n (cm^-3)        p (cm^-3)        sigma (S/cm)     RH (cm^3/C)      EF-Ei (eV)
#   300      2.841e-10      1.000e+14      8.072e-34      1.602e-02     -6.242e+04        1.402
#   450      9.399e-01      1.000e+14      8.834e-15      1.602e-02     -6.242e+04        1.252
#   600      5.406e+04      1.000e+14      2.922e-05      1.602e-02     -6.242e+04        1.103

# %% [markdown]
# ## Reflection and discussion questions
# 1. In Part A, which material had the smallest intrinsic carrier concentration, and how does that connect to its band gap?
# 2. In Part B, why does the hole concentration decrease as donor doping increases even though the temperature is unchanged?
# 3. Why does conductivity increase with donor doping, while the magnitude of the Hall coefficient decreases?
# 4. Why does the Fermi level move upward relative to the intrinsic level as \(N_D\) increases?
# 5. In Part C, why does silicon move closer to intrinsic behavior at high temperature, while GaN remains strongly extrinsic?
#
# ## Suggested extensions for students
# 1. Repeat Part B for **p-type silicon** by setting \(N_D=0\) and
# \[
# N_A = [10^{14},\;10^{15},\;10^{16},\;10^{17},\;10^{18}] \;\mathrm{cm^{-3}}
# \]
# and then adapt the Hall-coefficient sign accordingly.
# 2. Add **Ge** and **SiC** to Part C and compare all four materials on the same temperature plots.
# 3. Repeat Part C for a higher donor density, such as \(N_D = 10^{16}\,\mathrm{cm^{-3}}\), and explain how stronger doping delays intrinsic takeover.
# 4. Replace the single-carrier Hall-coefficient estimate with the full two-carrier Hall expression and compare the results near intrinsic conditions.
